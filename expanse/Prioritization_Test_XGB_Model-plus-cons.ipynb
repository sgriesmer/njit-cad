# %% [markdown]
# ## Installation

# %% [markdown]
# Installing Bio, transformers, genomic-benchmarks, and datasets packages.  The Bio package is from Biopython; transformers package for machine learning (pytorch, tensorflow); genomic-benchmarks and datasets from ML-Bioinfo-CEITEC.

# %%
# already set up on Expanse; toggle for colab

# pip install -qq Bio transformers genomic-benchmarks datasets transformers[torch] pyfaidx

# %% [markdown]
# Set path prefix for Expanse

# %%
path_prefix = "/expanse/lustre/projects/nji102/sgriesmer/"

# %% [markdown]
# Import SNP datasets

# %%
# set model name

# model name is "REG_CADD_cons", "PAT_CADD_cons", "CAN_CADD_cons", "REG_CADD_cons_default", or "CAN_CADD_cons_default"
model_name = "PAT_CADD_cons_default"

# %%
from joblib import dump, load

test_estimator = load('/expanse/lustre/projects/nji102/sgriesmer/DNABERT_2/Output_Models/model_xpg_boost_PRVCS_' + model_name + '.joblib')
# Out:
# /cm/shared/apps/spack/0.17.3/cpu/b/opt/spack/linux-rocky8-zen/gcc-8.5.0/anaconda3-2021.05-q4munrgvh7qp4o7r3nzcdkbuph4z7375/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# Load Rate_Patho dataset

# %%
import pandas as pd

path_prefix = "/expanse/lustre/projects/nji102/sgriesmer/"

RARPAT_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/RARPAT_0_102-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
RARPAT_abs_diff_plus_log_odds_scores_norm.shape
# Out:
# (102, 1380)

# %% [markdown]
# Import conservation scores

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Rare_Patho_SNV_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (         Name  priPhCons  priPhyloP  GerpN  GerpS
#  0  RARPAT0001      0.001     -3.552   4.26 -6.250
#  1  RARPAT0002      0.021     -1.482   4.36 -3.380
#  2  RARPAT0003      0.000     -3.401   4.09 -3.280
#  3  RARPAT0004      0.097      0.255   2.12  0.856
#  4  RARPAT0005      0.069     -0.558   2.47 -4.950,
#  (102, 5))

# %%
cons_scores
# Out:
#            Name  priPhCons  priPhyloP  GerpN   GerpS
# 0    RARPAT0001      0.001     -3.552   4.26 -6.2500
# 1    RARPAT0002      0.021     -1.482   4.36 -3.3800
# 2    RARPAT0003      0.000     -3.401   4.09 -3.2800
# 3    RARPAT0004      0.097      0.255   2.12  0.8560
# 4    RARPAT0005      0.069     -0.558   2.47 -4.9500
# ..          ...        ...        ...    ...     ...
# 97   RARPAT0098      0.956      0.597   5.66  5.6600
# 98   RARPAT0099      0.916      0.597   5.14  0.0847
# 99   RARPAT0100      0.029      0.484   4.10  0.2040
# 100  RARPAT0101      0.001     -0.255   4.26 -4.4600
# 101  RARPAT0102      0.050     -0.381   5.25 -2.9100
#
# [102 rows x 5 columns]

# %% [markdown]
# Drop name column before concatenating

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#      priPhCons  priPhyloP  GerpN   GerpS
# 0        0.001     -3.552   4.26 -6.2500
# 1        0.021     -1.482   4.36 -3.3800
# 2        0.000     -3.401   4.09 -3.2800
# 3        0.097      0.255   2.12  0.8560
# 4        0.069     -0.558   2.47 -4.9500
# ..         ...        ...    ...     ...
# 97       0.956      0.597   5.66  5.6600
# 98       0.916      0.597   5.14  0.0847
# 99       0.029      0.484   4.10  0.2040
# 100      0.001     -0.255   4.26 -4.4600
# 101      0.050     -0.381   5.25 -2.9100
#
# [102 rows x 4 columns]

# %% [markdown]
# Normalize conservation scores

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#      priPhCons  priPhyloP     GerpN     GerpS
# 0    -0.804896  -5.978133  1.105324 -3.074966
# 1    -0.702284  -2.482164  1.180027 -1.709069
# 2    -0.810026  -5.723113  0.978329 -1.661477
# 3    -0.312361   0.451409 -0.493317  0.306939
# 4    -0.456017  -0.921645 -0.231857 -2.456267
# ..         ...        ...       ...       ...
# 97    4.094798   1.029004  2.151165  2.593270
# 98    3.889575   1.029004  1.762710 -0.060140
# 99   -0.661240   0.838162  0.985800 -0.003363
# 100  -0.804896  -0.409916  1.105324 -2.223065
# 101  -0.553498  -0.622714  1.844883 -1.485385
#
# [102 rows x 4 columns]

# %% [markdown]
# Concatenate chromatin feature scores and conservation scores

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([RARPAT_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#      BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                     -0.206538                         2.906377
# 1                     -0.199992                        -0.375900
# 2                     -0.206664                        -0.596656
# 3                     -0.206959                        -0.652848
# 4                     -0.206414                        -0.607214
# ..                          ...                              ...
# 97                     0.358051                         1.170373
# 98                     0.395013                         3.306250
# 99                     1.713206                        -0.532519
# 100                   -0.206210                         0.352594
# 101                   -0.206418                        -0.190577
#
#      BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                       -0.170420                           0.426654
# 1                       -0.181145                           0.090514
# 2                        0.064562                          -0.834445
# 3                       -0.199506                          -1.051992
# 4                       -0.142333                          -0.135244
# ..                            ...                                ...
# 97                       0.535112                           0.557339
# 98                       0.176883                           0.839464
# 99                       0.096789                           0.765235
# 100                     -0.198994                          -0.541340
# 101                     -0.199462                          -0.646232
#
#      BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                               4.482777                    -0.250790
# 1                              -0.511342                    -0.245346
# 2                              -0.511587                    -0.200498
# 3                              -0.511260                    -0.250757
# 4                              -0.511261                    -0.250779
# ..                                   ...                          ...
# 97                             -0.139149                    -0.221604
# 98                              0.098059                    -0.159920
# 99                              2.301548                    -0.026938
# 100                            -0.498336                    -0.250799
# 101                            -0.500907                    -0.250379
#
#      BroadH1hescEzh239875UniPk151-ran  BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                           -0.309892                              -0.490882
# 1                           -0.315248                              -0.518109
# 2                           -0.315569                              -0.146835
# 3                           -0.315690                              -0.531651
# 4                           -0.314809                              -0.530276
# ..                                ...                                    ...
# 97                          -0.294488                              -0.465753
# 98                          -0.292982                              -0.471717
# 99                          -0.315642                              -0.385426
# 100                          1.820070                              -0.310376
# 101                         -0.315727                              -0.309261
#
#      BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                                1.445626                    -0.223756  ...
# 1                               -0.447039                    -0.203248  ...
# 2                               -0.445965                    -0.220517  ...
# 3                               -0.447218                    -0.225224  ...
# 4                               -0.366058                    -0.225169  ...
# ..                                    ...                          ...  ...
# 97                              -0.089202                    -0.127893  ...
# 98                               0.924219                    -0.163577  ...
# 99                              -0.442458                     0.458197  ...
# 100                              0.780945                    -0.225134  ...
# 101                             -0.446197                    -0.170776  ...
#
#      UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                   -0.345971                  -0.380637
# 1                    0.005478                  -0.285432
# 2                    0.588175                   0.127299
# 3                   -0.414731                  -0.393139
# 4                   -0.283245                  -0.315174
# ..                        ...                        ...
# 97                  -0.301338                  -0.008619
# 98                  -0.416086                  -0.071533
# 99                   0.099295                   0.810668
# 100                 -0.071771                  -0.149783
# 101                 -0.334768                   0.012277
#
#      UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                   -0.121216                    -0.384348
# 1                   -0.564576                    -0.375864
# 2                   -0.620407                    -0.369813
# 3                   -0.635052                    -0.382570
# 4                    1.199907                    -0.343330
# ..                        ...                          ...
# 97                  -0.463245                     0.107149
# 98                  -0.495524                    -0.187121
# 99                  -0.066553                    -0.376010
# 100                 -0.630602                    -0.381858
# 101                  2.361952                    -0.368337
#
#      UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1  priPhCons  \
# 0                      -0.293211                 -0.380950  -0.804896
# 1                      -0.276490                 -0.429664  -0.702284
# 2                       1.355054                  0.490738  -0.810026
# 3                      -0.302146                 -0.436147  -0.312361
# 4                      -0.283350                 -0.238857  -0.456017
# ..                           ...                       ...        ...
# 97                     -0.249296                 -0.181547   4.094798
# 98                     -0.251338                 -0.333898   3.889575
# 99                      0.247688                  0.248135  -0.661240
# 100                    -0.303848                 -0.410570  -0.804896
# 101                    -0.298699                 -0.305140  -0.553498
#
#      priPhyloP     GerpN     GerpS
# 0    -5.978133  1.105324 -3.074966
# 1    -2.482164  1.180027 -1.709069
# 2    -5.723113  0.978329 -1.661477
# 3     0.451409 -0.493317  0.306939
# 4    -0.921645 -0.231857 -2.456267
# ..         ...       ...       ...
# 97    1.029004  2.151165  2.593270
# 98    1.029004  1.762710 -0.060140
# 99    0.838162  0.985800 -0.003363
# 100  -0.409916  1.105324 -2.223065
# 101  -0.622714  1.844883 -1.485385
#
# [102 rows x 1384 columns]

# %%
# Set model names to numbers

# %%
col_lab = list(range(0,1384))
RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm = RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.206538  2.906377 -0.170420  0.426654  4.482777 -0.250790 -0.309892
# 1   -0.199992 -0.375900 -0.181145  0.090514 -0.511342 -0.245346 -0.315248
# 2   -0.206664 -0.596656  0.064562 -0.834445 -0.511587 -0.200498 -0.315569
# 3   -0.206959 -0.652848 -0.199506 -1.051992 -0.511260 -0.250757 -0.315690
# 4   -0.206414 -0.607214 -0.142333 -0.135244 -0.511261 -0.250779 -0.314809
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.358051  1.170373  0.535112  0.557339 -0.139149 -0.221604 -0.294488
# 98   0.395013  3.306250  0.176883  0.839464  0.098059 -0.159920 -0.292982
# 99   1.713206 -0.532519  0.096789  0.765235  2.301548 -0.026938 -0.315642
# 100 -0.206210  0.352594 -0.198994 -0.541340 -0.498336 -0.250799  1.820070
# 101 -0.206418 -0.190577 -0.199462 -0.646232 -0.500907 -0.250379 -0.315727
#
#          7         8         9     ...      1374      1375      1376  \
# 0   -0.490882  1.445626 -0.223756  ... -0.345971 -0.380637 -0.121216
# 1   -0.518109 -0.447039 -0.203248  ...  0.005478 -0.285432 -0.564576
# 2   -0.146835 -0.445965 -0.220517  ...  0.588175  0.127299 -0.620407
# 3   -0.531651 -0.447218 -0.225224  ... -0.414731 -0.393139 -0.635052
# 4   -0.530276 -0.366058 -0.225169  ... -0.283245 -0.315174  1.199907
# ..        ...       ...       ...  ...       ...       ...       ...
# 97  -0.465753 -0.089202 -0.127893  ... -0.301338 -0.008619 -0.463245
# 98  -0.471717  0.924219 -0.163577  ... -0.416086 -0.071533 -0.495524
# 99  -0.385426 -0.442458  0.458197  ...  0.099295  0.810668 -0.066553
# 100 -0.310376  0.780945 -0.225134  ... -0.071771 -0.149783 -0.630602
# 101 -0.309261 -0.446197 -0.170776  ... -0.334768  0.012277  2.361952
#
#          1377      1378      1379      1380      1381      1382      1383
# 0   -0.384348 -0.293211 -0.380950 -0.804896 -5.978133  1.105324 -3.074966
# 1   -0.375864 -0.276490 -0.429664 -0.702284 -2.482164  1.180027 -1.709069
# 2   -0.369813  1.355054  0.490738 -0.810026 -5.723113  0.978329 -1.661477
# 3   -0.382570 -0.302146 -0.436147 -0.312361  0.451409 -0.493317  0.306939
# 4   -0.343330 -0.283350 -0.238857 -0.456017 -0.921645 -0.231857 -2.456267
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.107149 -0.249296 -0.181547  4.094798  1.029004  2.151165  2.593270
# 98  -0.187121 -0.251338 -0.333898  3.889575  1.029004  1.762710 -0.060140
# 99  -0.376010  0.247688  0.248135 -0.661240  0.838162  0.985800 -0.003363
# 100 -0.381858 -0.303848 -0.410570 -0.804896 -0.409916  1.105324 -2.223065
# 101 -0.368337 -0.298699 -0.305140 -0.553498 -0.622714  1.844883 -1.485385
#
# [102 rows x 1384 columns]

# %%
RARPAT_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Rare_Patho_SNV_dataset_XY-named.txt", sep='\t')

# %%
y = RARPAT_prvcs['label']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 97     1
# 98     1
# 99     1
# 100    0
# 101    1
# Name: label, Length: 102, dtype: int64

# %%
RARPAT_pred = test_estimator.predict(RARPAT_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef, roc_auc_score, average_precision_score

print("Accuracy_model_REG: %.4f" % (accuracy_score(y, RARPAT_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, RARPAT_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, RARPAT_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , RARPAT_pred)))
print("ROC_PRC_model_REG: %.4f" % (average_precision_score(y , RARPAT_pred)))
# Out:
# Accuracy_model_REG: 0.5686
# F1_model_REG: 0.0000
# MCC_model_REG: 0.0000
# ROC_AUC_model_REG: 0.5000
# ROC_PRC_model_REG: 0.4314
# /cm/shared/apps/spack/0.17.3/cpu/b/opt/spack/linux-rocky8-zen/gcc-8.5.0/anaconda3-2021.05-q4munrgvh7qp4o7r3nzcdkbuph4z7375/lib/python3.8/site-packages/sklearn/metrics/_classification.py:870: RuntimeWarning: invalid value encountered in scalar divide
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %% [markdown]
# Load ASD dataset

# %%
ASD_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/ASD_0_107-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %% [markdown]
# Import conservation scores

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/ASD_denovo_SNV_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (      Name  priPhCons  priPhyloP  GerpN  GerpS
#  0  ASD0001      0.064      0.462  0.427  0.427
#  1  ASD0002      0.023      0.393  2.570  1.350
#  2  ASD0003      0.002     -1.411  2.900 -4.580
#  3  ASD0004      0.010     -0.650  0.626 -1.250
#  4  ASD0005      0.019      0.462  4.400  3.480,
#  (107, 5))

# %%
cons_scores
# Out:
#         Name  priPhCons  priPhyloP  GerpN  GerpS
# 0    ASD0001      0.064      0.462  0.427  0.427
# 1    ASD0002      0.023      0.393  2.570  1.350
# 2    ASD0003      0.002     -1.411  2.900 -4.580
# 3    ASD0004      0.010     -0.650  0.626 -1.250
# 4    ASD0005      0.019      0.462  4.400  3.480
# ..       ...        ...        ...    ...    ...
# 102  ASD0103      0.677     -0.532  3.260 -3.500
# 103  ASD0104      0.093      0.198  0.930  0.930
# 104  ASD0105      0.001     -1.824  2.380 -4.330
# 105  ASD0106      0.044     -1.067  2.880  0.648
# 106  ASD0107      0.037      0.480  3.170  3.170
#
# [107 rows x 5 columns]

# %% [markdown]
# Drop name column before concatenating

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#      priPhCons  priPhyloP  GerpN  GerpS
# 0        0.064      0.462  0.427  0.427
# 1        0.023      0.393  2.570  1.350
# 2        0.002     -1.411  2.900 -4.580
# 3        0.010     -0.650  0.626 -1.250
# 4        0.019      0.462  4.400  3.480
# ..         ...        ...    ...    ...
# 102      0.677     -0.532  3.260 -3.500
# 103      0.093      0.198  0.930  0.930
# 104      0.001     -1.824  2.380 -4.330
# 105      0.044     -1.067  2.880  0.648
# 106      0.037      0.480  3.170  3.170
#
# [107 rows x 4 columns]

# %% [markdown]
# Normalize conservation scores

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#      priPhCons  priPhyloP     GerpN     GerpS
# 0    -0.411880   0.639408 -1.844404  0.252143
# 1    -0.538299   0.546163 -0.395911  0.582231
# 2    -0.603051  -1.891741 -0.172858 -1.538488
# 3    -0.578384  -0.863335 -1.709897 -0.347595
# 4    -0.550633   0.639408  0.841019  1.343973
# ..         ...        ...       ...       ...
# 102   1.478249  -0.703871  0.070472 -1.152253
# 103  -0.322461   0.282642 -1.504417  0.432028
# 104  -0.606134  -2.449864 -0.524336 -1.449082
# 105  -0.473548  -1.426863 -0.186377  0.331178
# 106  -0.495132   0.663733  0.009640  1.233109
#
# [107 rows x 4 columns]

# %% [markdown]
# Concatenate chromatin feature scores and conservation scores

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
ASD_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([ASD_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
ASD_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#      BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                     -0.229695                        -0.602858
# 1                     -0.229542                        -0.607343
# 2                     -0.229701                        -0.664080
# 3                     -0.229476                        -0.584708
# 4                     -0.225621                         1.027578
# ..                          ...                              ...
# 102                   -0.214256                        -0.687476
# 103                   -0.208566                        -0.606097
# 104                   -0.229132                         0.378171
# 105                   -0.225772                        -0.358270
# 106                   -0.145310                         0.097247
#
#      BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                       -0.290626                          -0.089052
# 1                       -0.285806                           0.696796
# 2                       -0.290600                          -0.174744
# 3                       -0.290655                          -0.789959
# 4                       -0.278320                          -0.599621
# ..                            ...                                ...
# 102                     -0.016445                          -0.741008
# 103                      0.049127                          -0.549999
# 104                     -0.278365                          -0.783417
# 105                     -0.251520                           2.095907
# 106                      0.994418                          -0.440804
#
#      BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                              -0.163430                    -0.288711
# 1                              -0.466199                    -0.288711
# 2                              -0.453984                    -0.288711
# 3                              -0.462516                    -0.288706
# 4                               0.840352                    -0.288705
# ..                                   ...                          ...
# 102                            -0.467378                    -0.073159
# 103                            -0.467226                    -0.140918
# 104                            -0.409220                    -0.283918
# 105                            -0.113983                    -0.288496
# 106                             0.501871                     0.492719
#
#      BroadH1hescEzh239875UniPk151-ran  BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                           -0.374899                              -0.487998
# 1                           -0.372011                              -0.445119
# 2                           -0.370807                              -0.534545
# 3                           -0.362875                              -0.532215
# 4                           -0.152654                              -0.550221
# ..                                ...                                    ...
# 102                         -0.376444                              -0.554693
# 103                         -0.224215                               0.030520
# 104                         -0.325528                              -0.119599
# 105                          0.223446                               0.162861
# 106                         -0.367708                              -0.462603
#
#      BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                               -0.477156                    -0.318228  ...
# 1                               -0.462745                    -0.319469  ...
# 2                               -0.476378                    -0.319586  ...
# 3                               -0.300705                    -0.318731  ...
# 4                               -0.469771                    -0.319039  ...
# ..                                    ...                          ...  ...
# 102                             -0.475152                    -0.310869  ...
# 103                             -0.138759                    -0.291726  ...
# 104                             -0.337254                    -0.318836  ...
# 105                              0.770044                    -0.319727  ...
# 106                             -0.316198                     1.021882  ...
#
#      UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                   -0.545594                  -0.354866
# 1                   -0.535811                  -0.428614
# 2                   -0.543638                  -0.424393
# 3                   -0.475389                  -0.288862
# 4                   -0.556688                  -0.389388
# ..                        ...                        ...
# 102                 -0.394164                  -0.244371
# 103                  0.079465                  -0.430403
# 104                 -0.359191                  -0.269229
# 105                  0.025542                  -0.288175
# 106                  1.464565                  -0.122581
#
#      UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                   -0.323475                    -0.450354
# 1                   -0.507799                    -0.450341
# 2                   -0.374857                    -0.436132
# 3                    1.355761                    -0.446610
# 4                   -0.598057                    -0.362129
# ..                        ...                          ...
# 102                 -0.620546                    -0.432624
# 103                 -0.487613                    -0.384336
# 104                 -0.161170                    -0.440565
# 105                  0.650125                     1.904538
# 106                 -0.179194                     0.711533
#
#      UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1  priPhCons  \
# 0                      -0.393204                 -0.429022  -0.411880
# 1                      -0.392362                 -0.331279  -0.538299
# 2                      -0.388976                 -0.426025  -0.603051
# 3                      -0.392134                 -0.398144  -0.578384
# 4                      -0.394222                 -0.415341  -0.550633
# ..                           ...                       ...        ...
# 102                    -0.283490                 -0.293363   1.478249
# 103                    -0.120339                  1.260034  -0.322461
# 104                     0.254996                 -0.370670  -0.606134
# 105                    -0.381119                 -0.345916  -0.473548
# 106                     0.182346                 -0.185720  -0.495132
#
#      priPhyloP     GerpN     GerpS
# 0     0.639408 -1.844404  0.252143
# 1     0.546163 -0.395911  0.582231
# 2    -1.891741 -0.172858 -1.538488
# 3    -0.863335 -1.709897 -0.347595
# 4     0.639408  0.841019  1.343973
# ..         ...       ...       ...
# 102  -0.703871  0.070472 -1.152253
# 103   0.282642 -1.504417  0.432028
# 104  -2.449864 -0.524336 -1.449082
# 105  -1.426863 -0.186377  0.331178
# 106   0.663733  0.009640  1.233109
#
# [107 rows x 1384 columns]

# %%
# Set model names to numbers

# %%
col_lab = list(range(0,1384))
ASD_abs_diff_plus_log_odds_and_cons_scores_norm = ASD_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
ASD_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.229695 -0.602858 -0.290626 -0.089052 -0.163430 -0.288711 -0.374899
# 1   -0.229542 -0.607343 -0.285806  0.696796 -0.466199 -0.288711 -0.372011
# 2   -0.229701 -0.664080 -0.290600 -0.174744 -0.453984 -0.288711 -0.370807
# 3   -0.229476 -0.584708 -0.290655 -0.789959 -0.462516 -0.288706 -0.362875
# 4   -0.225621  1.027578 -0.278320 -0.599621  0.840352 -0.288705 -0.152654
# ..        ...       ...       ...       ...       ...       ...       ...
# 102 -0.214256 -0.687476 -0.016445 -0.741008 -0.467378 -0.073159 -0.376444
# 103 -0.208566 -0.606097  0.049127 -0.549999 -0.467226 -0.140918 -0.224215
# 104 -0.229132  0.378171 -0.278365 -0.783417 -0.409220 -0.283918 -0.325528
# 105 -0.225772 -0.358270 -0.251520  2.095907 -0.113983 -0.288496  0.223446
# 106 -0.145310  0.097247  0.994418 -0.440804  0.501871  0.492719 -0.367708
#
#          7         8         9     ...      1374      1375      1376  \
# 0   -0.487998 -0.477156 -0.318228  ... -0.545594 -0.354866 -0.323475
# 1   -0.445119 -0.462745 -0.319469  ... -0.535811 -0.428614 -0.507799
# 2   -0.534545 -0.476378 -0.319586  ... -0.543638 -0.424393 -0.374857
# 3   -0.532215 -0.300705 -0.318731  ... -0.475389 -0.288862  1.355761
# 4   -0.550221 -0.469771 -0.319039  ... -0.556688 -0.389388 -0.598057
# ..        ...       ...       ...  ...       ...       ...       ...
# 102 -0.554693 -0.475152 -0.310869  ... -0.394164 -0.244371 -0.620546
# 103  0.030520 -0.138759 -0.291726  ...  0.079465 -0.430403 -0.487613
# 104 -0.119599 -0.337254 -0.318836  ... -0.359191 -0.269229 -0.161170
# 105  0.162861  0.770044 -0.319727  ...  0.025542 -0.288175  0.650125
# 106 -0.462603 -0.316198  1.021882  ...  1.464565 -0.122581 -0.179194
#
#          1377      1378      1379      1380      1381      1382      1383
# 0   -0.450354 -0.393204 -0.429022 -0.411880  0.639408 -1.844404  0.252143
# 1   -0.450341 -0.392362 -0.331279 -0.538299  0.546163 -0.395911  0.582231
# 2   -0.436132 -0.388976 -0.426025 -0.603051 -1.891741 -0.172858 -1.538488
# 3   -0.446610 -0.392134 -0.398144 -0.578384 -0.863335 -1.709897 -0.347595
# 4   -0.362129 -0.394222 -0.415341 -0.550633  0.639408  0.841019  1.343973
# ..        ...       ...       ...       ...       ...       ...       ...
# 102 -0.432624 -0.283490 -0.293363  1.478249 -0.703871  0.070472 -1.152253
# 103 -0.384336 -0.120339  1.260034 -0.322461  0.282642 -1.504417  0.432028
# 104 -0.440565  0.254996 -0.370670 -0.606134 -2.449864 -0.524336 -1.449082
# 105  1.904538 -0.381119 -0.345916 -0.473548 -1.426863 -0.186377  0.331178
# 106  0.711533  0.182346 -0.185720 -0.495132  0.663733  0.009640  1.233109
#
# [107 rows x 1384 columns]

# %%
ASD_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/ASD_denovo_SNV_dataset_XY-named.txt", sep='\t')

# %%
y = ASD_prvcs['label']

# %%
ASD_pred = test_estimator.predict(ASD_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, ASD_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, ASD_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, ASD_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , ASD_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , ASD_pred)))
# Out:
# Accuracy_model_REG: 0.4766
# F1_model_REG: 0.0345
# MCC_model_REG: 0.0910
# ROC_AUC_model_REG: 0.5088
# Avg_Recall_Score_model_REG: 0.5409

# %% [markdown]
# Load GTEx dataset

# %%
GTEX_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/GTEX_0_796-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GTEx_eQTL_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (       Name  priPhCons  priPhyloP  GerpN  GerpS
#  0  GTEX0001      0.007      0.375  1.150  1.150
#  1  GTEX0002      0.115     -0.033  1.909 -0.200
#  2  GTEX0003      0.115     -0.033  1.909 -0.200
#  3  GTEX0004      0.000     -0.600  1.960 -0.495
#  4  GTEX0005      0.026      0.387  1.250 -1.360,
#  (796, 5))

# %%
cons_scores
# Out:
#          Name  priPhCons  priPhyloP  GerpN  GerpS
# 0    GTEX0001      0.007      0.375  1.150  1.150
# 1    GTEX0002      0.115     -0.033  1.909 -0.200
# 2    GTEX0003      0.115     -0.033  1.909 -0.200
# 3    GTEX0004      0.000     -0.600  1.960 -0.495
# 4    GTEX0005      0.026      0.387  1.250 -1.360
# ..        ...        ...        ...    ...    ...
# 791  GTEX0792      0.115     -0.033  1.909 -0.200
# 792  GTEX0793      0.034      0.146  0.149  0.149
# 793  GTEX0794      0.115     -0.033  1.909 -0.200
# 794  GTEX0795      0.115     -0.033  1.909 -0.200
# 795  GTEX0796      0.115     -0.033  1.909 -0.200
#
# [796 rows x 5 columns]

# %% [markdown]
# Drop name column before concatenating

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#      priPhCons  priPhyloP  GerpN  GerpS
# 0        0.007      0.375  1.150  1.150
# 1        0.115     -0.033  1.909 -0.200
# 2        0.115     -0.033  1.909 -0.200
# 3        0.000     -0.600  1.960 -0.495
# 4        0.026      0.387  1.250 -1.360
# ..         ...        ...    ...    ...
# 791      0.115     -0.033  1.909 -0.200
# 792      0.034      0.146  0.149  0.149
# 793      0.115     -0.033  1.909 -0.200
# 794      0.115     -0.033  1.909 -0.200
# 795      0.115     -0.033  1.909 -0.200
#
# [796 rows x 4 columns]

# %% [markdown]
# Normalize conservation scores

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#      priPhCons  priPhyloP     GerpN     GerpS
# 0    -0.909252   1.207975 -0.986787  1.188003
# 1     0.007110   0.063071 -0.059739  0.073786
# 2     0.007110   0.063071 -0.059739  0.073786
# 3    -0.968646  -1.528009  0.002553 -0.169691
# 4    -0.748040   1.241649 -0.864647 -0.883615
# ..         ...        ...       ...       ...
# 791   0.007110   0.063071 -0.059739  0.073786
# 792  -0.680161   0.565370 -2.209417  0.361832
# 793   0.007110   0.063071 -0.059739  0.073786
# 794   0.007110   0.063071 -0.059739  0.073786
# 795   0.007110   0.063071 -0.059739  0.073786
#
# [796 rows x 4 columns]

# %% [markdown]
# Concatenate chromatin feature scores and conservation scores

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
GTEX_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([GTEX_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
GTEX_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#      BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                     -0.178355                        -0.485832
# 1                     -0.178352                        -0.246669
# 2                     -0.178302                        -0.517851
# 3                     -0.178280                        -0.375803
# 4                     -0.178030                         0.393779
# ..                          ...                              ...
# 791                    0.198956                        -0.526851
# 792                    0.018531                        -0.162753
# 793                   -0.178362                        -0.528672
# 794                    0.076135                        -0.512977
# 795                   -0.160401                        -0.511978
#
#      BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                       -0.224357                          -0.385733
# 1                       -0.221942                           0.956891
# 2                       -0.224342                          -0.729727
# 3                       -0.223981                          -0.385835
# 4                       -0.223855                          -0.137609
# ..                            ...                                ...
# 791                      0.979379                          -0.594531
# 792                      0.481206                           0.670652
# 793                     -0.224362                          -0.726840
# 794                      0.433604                          -0.214048
# 795                      1.923092                          -0.336154
#
#      BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                              -0.429759                    -0.209388
# 1                               3.155623                    -0.209369
# 2                              -0.162195                    -0.209389
# 3                               0.343213                    -0.209360
# 4                               1.212573                    -0.209318
# ..                                   ...                          ...
# 791                            -0.429889                    -0.201291
# 792                            -0.429505                    -0.190066
# 793                            -0.429889                    -0.209386
# 794                            -0.429695                    -0.193048
# 795                            -0.429076                    -0.208999
#
#      BroadH1hescEzh239875UniPk151-ran  BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                           -0.244968                              -0.468064
# 1                           -0.240326                               0.142329
# 2                           -0.243257                              -0.470614
# 3                           -0.244811                              -0.464363
# 4                            4.905893                               2.569003
# ..                                ...                                    ...
# 791                         -0.244975                              -0.471995
# 792                         -0.237247                              -0.270271
# 793                         -0.244985                              -0.470701
# 794                         -0.241100                               0.658683
# 795                         -0.244978                              -0.466689
#
#      BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                               -0.360461                    -0.188559  ...
# 1                                2.235803                    -0.153395  ...
# 2                               -0.358797                    -0.188556  ...
# 3                               -0.129742                    -0.187047  ...
# 4                                1.323787                    -0.184953  ...
# ..                                    ...                          ...  ...
# 791                             -0.360122                    -0.184072  ...
# 792                              0.260414                    -0.146905  ...
# 793                             -0.360351                    -0.188561  ...
# 794                             -0.340889                    -0.169407  ...
# 795                             -0.313421                    -0.128975  ...
#
#      UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                   -0.289796                  -0.205919
# 1                   -0.169110                   0.110825
# 2                   -0.265715                  -0.264661
# 3                   -0.161633                  -0.151567
# 4                   -0.285058                  -0.317789
# ..                        ...                        ...
# 791                  0.367565                   0.833365
# 792                 -0.092712                  -0.073844
# 793                 -0.277991                  -0.332510
# 794                  1.220882                   0.182769
# 795                  0.390159                  -0.306720
#
#      UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                   -0.389517                    -0.261726
# 1                    0.377795                    -0.217207
# 2                   -0.455395                    -0.263826
# 3                    0.832964                    -0.253708
# 4                   -0.466421                    -0.265439
# ..                        ...                          ...
# 791                 -0.147515                     3.042131
# 792                 -0.302482                    -0.021024
# 793                 -0.463221                    -0.264702
# 794                 -0.101256                    -0.004808
# 795                  4.000024                     3.201575
#
#      UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1  priPhCons  \
# 0                      -0.260624                 -0.351443  -0.909252
# 1                      -0.253757                 -0.228107   0.007110
# 2                      -0.255614                 -0.323819   0.007110
# 3                      -0.236141                 -0.281717  -0.968646
# 4                      -0.254904                 -0.169747  -0.748040
# ..                           ...                       ...        ...
# 791                     0.044801                 -0.188965   0.007110
# 792                    -0.050756                 -0.149935  -0.680161
# 793                    -0.256798                 -0.348923   0.007110
# 794                    -0.217325                 -0.007000   0.007110
# 795                     0.862983                 -0.178033   0.007110
#
#      priPhyloP     GerpN     GerpS
# 0     1.207975 -0.986787  1.188003
# 1     0.063071 -0.059739  0.073786
# 2     0.063071 -0.059739  0.073786
# 3    -1.528009  0.002553 -0.169691
# 4     1.241649 -0.864647 -0.883615
# ..         ...       ...       ...
# 791   0.063071 -0.059739  0.073786
# 792   0.565370 -2.209417  0.361832
# 793   0.063071 -0.059739  0.073786
# 794   0.063071 -0.059739  0.073786
# 795   0.063071 -0.059739  0.073786
#
# [796 rows x 1384 columns]

# %%
# Set model names to numbers

# %%
col_lab = list(range(0,1384))
GTEX_abs_diff_plus_log_odds_and_cons_scores_norm = GTEX_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
GTEX_abs_diff_plus_log_odds_and_cons_scores_norm
# Out:
#          0         1         2         3         4         5         6     \
# 0   -0.178355 -0.485832 -0.224357 -0.385733 -0.429759 -0.209388 -0.244968
# 1   -0.178352 -0.246669 -0.221942  0.956891  3.155623 -0.209369 -0.240326
# 2   -0.178302 -0.517851 -0.224342 -0.729727 -0.162195 -0.209389 -0.243257
# 3   -0.178280 -0.375803 -0.223981 -0.385835  0.343213 -0.209360 -0.244811
# 4   -0.178030  0.393779 -0.223855 -0.137609  1.212573 -0.209318  4.905893
# ..        ...       ...       ...       ...       ...       ...       ...
# 791  0.198956 -0.526851  0.979379 -0.594531 -0.429889 -0.201291 -0.244975
# 792  0.018531 -0.162753  0.481206  0.670652 -0.429505 -0.190066 -0.237247
# 793 -0.178362 -0.528672 -0.224362 -0.726840 -0.429889 -0.209386 -0.244985
# 794  0.076135 -0.512977  0.433604 -0.214048 -0.429695 -0.193048 -0.241100
# 795 -0.160401 -0.511978  1.923092 -0.336154 -0.429076 -0.208999 -0.244978
#
#          7         8         9     ...      1374      1375      1376  \
# 0   -0.468064 -0.360461 -0.188559  ... -0.289796 -0.205919 -0.389517
# 1    0.142329  2.235803 -0.153395  ... -0.169110  0.110825  0.377795
# 2   -0.470614 -0.358797 -0.188556  ... -0.265715 -0.264661 -0.455395
# 3   -0.464363 -0.129742 -0.187047  ... -0.161633 -0.151567  0.832964
# 4    2.569003  1.323787 -0.184953  ... -0.285058 -0.317789 -0.466421
# ..        ...       ...       ...  ...       ...       ...       ...
# 791 -0.471995 -0.360122 -0.184072  ...  0.367565  0.833365 -0.147515
# 792 -0.270271  0.260414 -0.146905  ... -0.092712 -0.073844 -0.302482
# 793 -0.470701 -0.360351 -0.188561  ... -0.277991 -0.332510 -0.463221
# 794  0.658683 -0.340889 -0.169407  ...  1.220882  0.182769 -0.101256
# 795 -0.466689 -0.313421 -0.128975  ...  0.390159 -0.306720  4.000024
#
#          1377      1378      1379      1380      1381      1382      1383
# 0   -0.261726 -0.260624 -0.351443 -0.909252  1.207975 -0.986787  1.188003
# 1   -0.217207 -0.253757 -0.228107  0.007110  0.063071 -0.059739  0.073786
# 2   -0.263826 -0.255614 -0.323819  0.007110  0.063071 -0.059739  0.073786
# 3   -0.253708 -0.236141 -0.281717 -0.968646 -1.528009  0.002553 -0.169691
# 4   -0.265439 -0.254904 -0.169747 -0.748040  1.241649 -0.864647 -0.883615
# ..        ...       ...       ...       ...       ...       ...       ...
# 791  3.042131  0.044801 -0.188965  0.007110  0.063071 -0.059739  0.073786
# 792 -0.021024 -0.050756 -0.149935 -0.680161  0.565370 -2.209417  0.361832
# 793 -0.264702 -0.256798 -0.348923  0.007110  0.063071 -0.059739  0.073786
# 794 -0.004808 -0.217325 -0.007000  0.007110  0.063071 -0.059739  0.073786
# 795  3.201575  0.862983 -0.178033  0.007110  0.063071 -0.059739  0.073786
#
# [796 rows x 1384 columns]

# %%
GTEX_abs_diff_plus_log_odds_and_cons_scores_norm = GTEX_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
GTEX_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GTEx_eQTL_dataset_XY-named.txt", sep='\t')

# %%
y = GTEX_prvcs['label']

# %%
GTEX_pred = test_estimator.predict(GTEX_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, GTEX_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, GTEX_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, GTEX_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , GTEX_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , GTEX_pred)))
# Out:
# Accuracy_model_REG: 0.4912
# F1_model_REG: 0.0146
# MCC_model_REG: -0.0015
# ROC_AUC_model_REG: 0.4999
# Avg_Recall_Score_model_REG: 0.5087

# %% [markdown]
# Load Somatic eQTL dataset

# %%
SOMEQTL_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/SOMEQTL_0_7513-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Somatic_eQTL_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (           Name  priPhCons  priPhyloP  GerpN  GerpS
#  0  SOMEQTL00001      0.236      0.094   0.00  0.000
#  1  SOMEQTL00002      0.006     -0.398   3.13 -1.420
#  2  SOMEQTL00003      0.008     -0.821   4.49 -3.810
#  3  SOMEQTL00004      0.008     -0.146   3.32  1.450
#  4  SOMEQTL00005      0.010     -0.357   2.51  0.611,
#  (7513, 5))

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#       priPhCons  priPhyloP  GerpN  GerpS
# 0         0.236      0.094   0.00  0.000
# 1         0.006     -0.398   3.13 -1.420
# 2         0.008     -0.821   4.49 -3.810
# 3         0.008     -0.146   3.32  1.450
# 4         0.010     -0.357   2.51  0.611
# ...         ...        ...    ...    ...
# 7508      0.266      0.124   0.81 -0.189
# 7509      0.505      0.487   3.68  1.190
# 7510      0.014     -0.243   3.68 -1.990
# 7511      0.007     -0.483   2.97  0.243
# 7512      0.044      0.500   2.91 -3.020
#
# [7513 rows x 4 columns]

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#       priPhCons  priPhyloP     GerpN     GerpS
# 0      1.213221   0.183020 -2.072384  0.268571
# 1     -0.453869  -0.510635  0.063053 -0.252106
# 2     -0.439372  -1.107009  0.990910 -1.128457
# 3     -0.439372  -0.155348  0.192680  0.800248
# 4     -0.424876  -0.452830 -0.359941  0.492609
# ...         ...        ...       ...       ...
# 7508   1.430667   0.225316 -1.519763  0.199270
# 7509   3.162991   0.737098  0.438289  0.704913
# 7510  -0.395883  -0.292105  0.438289 -0.461110
# 7511  -0.446620  -0.630474 -0.046107  0.357673
# 7512  -0.178437   0.755426 -0.087042 -0.838784
#
# [7513 rows x 4 columns]

# %%
SOMEQTL_abs_diff_plus_log_odds_scores_norm
# Out:
#       BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                      -0.144903                         0.195737
# 1                      -0.144924                        -0.568833
# 2                      -0.144511                        -0.200158
# 3                      -0.144869                        -0.526162
# 4                      -0.144908                        -0.247975
# ...                          ...                              ...
# 7508                   -0.144305                        -0.367277
# 7509                   -0.144923                        -0.547270
# 7510                   -0.144899                        -0.591999
# 7511                   -0.143923                         0.127016
# 7512                   -0.143887                        -0.261605
#
#       BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                        -0.182222                          -0.108920
# 1                        -0.182462                          -0.683622
# 2                        -0.181925                          -0.358322
# 3                        -0.180201                           1.135465
# 4                        -0.141101                          -0.480016
# ...                            ...                                ...
# 7508                     -0.182471                          -0.244942
# 7509                     -0.182243                           1.006641
# 7510                     -0.182477                          -0.479671
# 7511                     -0.182166                           0.305013
# 7512                     -0.182206                           0.717491
#
#       BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                                0.215997                    -0.163565
# 1                               -0.434228                    -0.163565
# 2                               -0.394926                    -0.163529
# 3                                0.723396                    -0.163565
# 4                               -0.216463                    -0.150550
# ...                                   ...                          ...
# 7508                            -0.415514                    -0.163563
# 7509                            -0.432987                    -0.163565
# 7510                            -0.434303                    -0.163564
# 7511                            -0.262310                    -0.163462
# 7512                             0.328494                    -0.163562
#
#       BroadH1hescEzh239875UniPk151-ran  BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                            -0.275462                              -0.144383
# 1                            -0.275869                              -0.512477
# 2                            -0.275796                              -0.468553
# 3                            -0.237328                               0.449306
# 4                            -0.260551                               0.054881
# ...                                ...                                    ...
# 7508                         -0.243906                              -0.393012
# 7509                         -0.275755                               1.251890
# 7510                         -0.275865                              -0.517299
# 7511                         -0.275867                              -0.508464
# 7512                         -0.275589                              -0.501027
#
#       BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                                -0.338155                    -0.164474  ...
# 1                                -0.357202                    -0.164471  ...
# 2                                -0.354824                    -0.158311  ...
# 3                                -0.355735                    -0.163939  ...
# 4                                -0.087934                    -0.103180  ...
# ...                                    ...                          ...  ...
# 7508                             -0.113778                    -0.149147  ...
# 7509                             -0.357355                    -0.164476  ...
# 7510                             -0.357452                    -0.164468  ...
# 7511                             -0.357306                    -0.164449  ...
# 7512                              1.990147                    -0.161149  ...
#
#       UwMcf7CtcfUniPk151-ran.1  UwNb4CtcfUniPk151-ran.1  \
# 0                    -0.310175                -0.211341
# 1                    -0.342034                -0.200050
# 2                     0.963121                -0.209746
# 3                    -0.307590                -0.185465
# 4                     0.738351                 0.587462
# ...                        ...                      ...
# 7508                 -0.336289                -0.215802
# 7509                 -0.336786                -0.217042
# 7510                 -0.328957                -0.143269
# 7511                 -0.300933                -0.219915
# 7512                 -0.309396                -0.205722
#
#       UwNhdfneoCtcfUniPk151-ran.1  UwNhekCtcfUniPk151-ran.1  \
# 0                       -0.344102                 -0.265758
# 1                       -0.315634                 -0.105513
# 2                       -0.429988                 -0.135167
# 3                       -0.407711                 -0.259176
# 4                       -0.143264                  1.144424
# ...                           ...                       ...
# 7508                    -0.280409                 -0.196786
# 7509                    -0.349688                 -0.267488
# 7510                    -0.103965                 -0.264673
# 7511                    -0.351700                  0.076195
# 7512                    -0.358633                 -0.273524
#
#       UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                    -0.293365                  -0.196343
# 1                    -0.296193                  -0.337912
# 2                    -0.273474                   0.019215
# 3                    -0.181607                  -0.258805
# 4                     0.048478                  -0.293651
# ...                        ...                        ...
# 7508                 -0.278953                  -0.347581
# 7509                 -0.205523                  -0.333389
# 7510                 -0.296925                  -0.072538
# 7511                 -0.290894                   0.259330
# 7512                 -0.295221                  -0.020546
#
#       UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                    -0.520804                    -0.231279
# 1                    -0.506100                    -0.237790
# 2                    -0.320742                     0.107533
# 3                    -0.168069                    -0.238298
# 4                    -0.452174                    -0.230422
# ...                        ...                          ...
# 7508                  0.610747                    -0.238620
# 7509                 -0.438623                    -0.235375
# 7510                 -0.204852                    -0.234325
# 7511                 -0.246323                    -0.233290
# 7512                 -0.101558                    -0.234855
#
#       UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1
# 0                       -0.203031                 -0.333002
# 1                       -0.215480                 -0.324308
# 2                       -0.203012                 -0.307684
# 3                       -0.211773                 -0.291270
# 4                        0.445050                  0.516132
# ...                           ...                       ...
# 7508                    -0.216403                 -0.295181
# 7509                    -0.209342                 -0.246323
# 7510                    -0.212516                 -0.237920
# 7511                    -0.214649                 -0.301657
# 7512                    -0.215685                 -0.260686
#
# [7513 rows x 1380 columns]

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
SOMEQTL_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([SOMEQTL_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
col_lab = list(range(0,1384))
SOMEQTL_abs_diff_plus_log_odds_and_cons_scores_norm = SOMEQTL_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
SOMEQTL_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Somatic_eQTL_dataset_XY-named.txt", sep='\t')

# %%
y = SOMEQTL_prvcs['label']

# %%
SOMEQTL_pred = test_estimator.predict(SOMEQTL_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, SOMEQTL_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, SOMEQTL_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, SOMEQTL_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , SOMEQTL_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , SOMEQTL_pred)))
# Out:
# Accuracy_model_REG: 0.5096
# F1_model_REG: 0.0466
# MCC_model_REG: 0.0805
# ROC_AUC_model_REG: 0.5096
# Avg_Recall_Score_model_REG: 0.5079

# %% [markdown]
# Load GWAS E-8 Test Dataset

# %%
GWAS8_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/GWAS8_0_21725-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GWAS_SNP_5E-8_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (         Name  priPhCons  priPhyloP  GerpN  GerpS
#  0  GWAS800001      0.025      0.379  1.380  1.380
#  1  GWAS800002      0.130      0.158  0.122  0.122
#  2  GWAS800003      0.019     -2.070  0.000  0.000
#  3  GWAS800004      0.030      0.292  0.185  0.185
#  4  GWAS800005      0.010     -0.276  3.070 -6.140,
#  (21725, 5))

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#        priPhCons  priPhyloP  GerpN  GerpS
# 0          0.025      0.379  1.380  1.380
# 1          0.130      0.158  0.122  0.122
# 2          0.019     -2.070  0.000  0.000
# 3          0.030      0.292  0.185  0.185
# 4          0.010     -0.276  3.070 -6.140
# ...          ...        ...    ...    ...
# 21720      0.024     -1.400  0.000  0.000
# 21721      0.485      0.232  0.225  0.225
# 21722      0.068      0.232  0.614  0.614
# 21723      0.118      0.428  2.110 -0.425
# 21724      0.007      0.342  1.170 -2.070
#
# [21725 rows x 4 columns]

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#        priPhCons  priPhyloP     GerpN     GerpS
# 0      -0.364343   0.648509 -0.409791  0.801216
# 1       0.147629   0.353529 -1.174989  0.232482
# 2      -0.393598  -2.620293 -1.249198  0.177327
# 3      -0.339963   0.532386 -1.136669  0.260964
# 4      -0.437482  -0.225752  0.618179 -2.598529
# ...          ...        ...       ...       ...
# 21720  -0.369219  -1.726011 -1.249198  0.177327
# 21721   1.878580   0.452301 -1.112338  0.279048
# 21722  -0.154678   0.452301 -0.875723  0.454912
# 21723   0.089118   0.713912  0.034244 -0.014813
# 21724  -0.452109   0.599123 -0.537527 -0.758508
#
# [21725 rows x 4 columns]

# %%
GWAS8_abs_diff_plus_log_odds_scores_norm
# Out:
#        BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                       -0.129674                        -0.016937
# 1                       -0.129688                        -0.514675
# 2                       -0.129693                        -0.460933
# 3                       -0.129687                        -0.486871
# 4                       -0.129687                         2.089718
# ...                           ...                              ...
# 21720                   -0.157738                         4.305586
# 21721                   -0.158093                        -0.328668
# 21722                   -0.158077                         0.153827
# 21723                   -0.158063                        -0.526058
# 21724                   -0.158107                        -0.284551
#
#        BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                         -0.168857                          -0.612777
# 1                         -0.168928                          -0.653093
# 2                         -0.168930                          -0.647238
# 3                         -0.168916                          -0.632188
# 4                         -0.168791                           0.717755
# ...                             ...                                ...
# 21720                     -0.207253                           2.197794
# 21721                     -0.207312                           0.351229
# 21722                     -0.207308                          -0.652034
# 21723                     -0.207083                           0.427481
# 21724                     -0.207296                          -0.598775
#
#        BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                                 0.550565                    -0.147991
# 1                                -0.343035                    -0.147991
# 2                                -0.343096                    -0.147991
# 3                                -0.343080                    -0.147991
# 4                                 4.252767                    -0.147991
# ...                                    ...                          ...
# 21720                             7.406568                    -0.185714
# 21721                             0.727849                    -0.185714
# 21722                            -0.424610                    -0.185714
# 21723                            -0.418511                    -0.185681
# 21724                            -0.426994                    -0.185711
#
#        BroadH1hescEzh239875UniPk151-ran  \
# 0                             -0.040435
# 1                             -0.190363
# 2                             -0.190363
# 3                             -0.190187
# 4                             -0.190200
# ...                                 ...
# 21720                          2.152754
# 21721                         -0.247555
# 21722                         -0.247629
# 21723                         -0.247382
# 21724                         -0.247476
#
#        BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                                   0.180421
# 1                                  -0.455714
# 2                                  -0.427523
# 3                                  -0.438925
# 4                                   0.314753
# ...                                      ...
# 21720                               2.834862
# 21721                              -0.085751
# 21722                              -0.473976
# 21723                               0.057424
# 21724                              -0.511625
#
#        BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                                 -0.274353                    -0.144067  ...
# 1                                 -0.275306                    -0.144065  ...
# 2                                 -0.275103                    -0.144068  ...
# 3                                 -0.274875                    -0.144065  ...
# 4                                 -0.274302                    -0.144064  ...
# ...                                     ...                          ...  ...
# 21720                             -0.297445                    -0.179866  ...
# 21721                             -0.350369                    -0.184390  ...
# 21722                             -0.338721                    -0.184412  ...
# 21723                             -0.350206                    -0.184406  ...
# 21724                             -0.350693                    -0.184380  ...
#
#        UwMcf7CtcfUniPk151-ran.1  UwNb4CtcfUniPk151-ran.1  \
# 0                     -0.256078                -0.185529
# 1                     -0.244750                -0.185768
# 2                     -0.300975                -0.185886
# 3                     -0.252349                -0.178775
# 4                     -0.293252                -0.174759
# ...                         ...                      ...
# 21720                  0.430249                -0.184329
# 21721                 -0.334323                -0.227596
# 21722                 -0.360098                -0.221988
# 21723                  1.801114                -0.212217
# 21724                 -0.354077                -0.226167
#
#        UwNhdfneoCtcfUniPk151-ran.1  UwNhekCtcfUniPk151-ran.1  \
# 0                        -0.303280                 -0.211185
# 1                        -0.104093                 -0.218978
# 2                        -0.369799                 -0.281471
# 3                        -0.372817                 -0.159553
# 4                        -0.180935                 -0.272887
# ...                            ...                       ...
# 21720                     1.015918                 -0.222168
# 21721                    -0.453991                 -0.334762
# 21722                    -0.463599                 -0.282932
# 21723                    -0.115858                  0.098969
# 21724                    -0.446667                 -0.281945
#
#        UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                     -0.209141                   0.433344
# 1                     -0.217061                   0.138904
# 2                     -0.232661                  -0.335410
# 3                     -0.213912                  -0.178979
# 4                     -0.179814                  -0.308192
# ...                         ...                        ...
# 21720                 -0.219105                  -0.217155
# 21721                 -0.036078                  -0.296810
# 21722                 -0.279896                  -0.253956
# 21723                 -0.279897                  -0.312295
# 21724                 -0.140059                  -0.370739
#
#        UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                     -0.291560                    -0.204089
# 1                      2.757180                    -0.196721
# 2                     -0.443616                    -0.206673
# 3                     -0.421578                    -0.199231
# 4                      0.165941                    -0.208023
# ...                         ...                          ...
# 21720                  1.783749                    -0.254743
# 21721                 -0.114123                    -0.266907
# 21722                 -0.519972                    -0.266917
# 21723                 -0.512031                    -0.266037
# 21724                 -0.506091                    -0.265676
#
#        UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1
# 0                        -0.157390                 -0.227529
# 1                        -0.164951                 -0.263949
# 2                        -0.172934                 -0.280523
# 3                        -0.168021                 -0.242783
# 4                        -0.166212                 -0.258519
# ...                            ...                       ...
# 21720                    -0.212003                  1.471085
# 21721                    -0.222860                 -0.307631
# 21722                    -0.225591                 -0.328264
# 21723                    -0.094657                 -0.043703
# 21724                    -0.225360                 -0.311554
#
# [21725 rows x 1380 columns]

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
GWAS8_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([GWAS8_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
col_lab = list(range(0,1384))
GWAS8_abs_diff_plus_log_odds_and_cons_scores_norm = GWAS8_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
GWAS8_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GWAS_SNP_5E-8_dataset_XY-named.txt", sep='\t')

# %%
y = GWAS8_prvcs['label']

# %%
GWAS8_pred = test_estimator.predict(GWAS8_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, GWAS8_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, GWAS8_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, GWAS8_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , GWAS8_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , GWAS8_pred)))
# Out:
# Accuracy_model_REG: 0.5202
# F1_model_REG: 0.1150
# MCC_model_REG: 0.0889
# ROC_AUC_model_REG: 0.5183
# Avg_Recall_Score_model_REG: 0.5108

# %% [markdown]
# Load GWAS E-5 Test Dataset

# %%
GWAS5_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/GWAS5_0_60593-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GWAS_SNP_1E-5_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (         Name  priPhCons  priPhyloP   GerpN   GerpS
#  0  GWAS500001      0.005     -0.863  0.2350 -0.4700
#  1  GWAS500002      0.184      0.178  0.1130  0.1130
#  2  GWAS500003      0.721      0.249  1.1300 -1.5000
#  3  GWAS500004      0.002     -0.707  1.2600 -2.5200
#  4  GWAS500005      0.011      0.124  0.0465  0.0465,
#  (60593, 5))

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#        priPhCons  priPhyloP   GerpN   GerpS
# 0          0.005     -0.863  0.2350 -0.4700
# 1          0.184      0.178  0.1130  0.1130
# 2          0.721      0.249  1.1300 -1.5000
# 3          0.002     -0.707  1.2600 -2.5200
# 4          0.011      0.124  0.0465  0.0465
# ...          ...        ...     ...     ...
# 60588      0.068      0.232  0.6140  0.6140
# 60589      0.021     -0.667  0.6370 -1.2700
# 60590      0.118      0.428  2.1100 -0.4250
# 60591      0.007      0.342  1.1700 -2.0700
# 60592      0.003     -0.391  2.2600 -0.5850
#
# [60593 rows x 4 columns]

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#        priPhCons  priPhyloP     GerpN     GerpS
# 0      -0.448015  -1.022180 -1.088748 -0.013349
# 1       0.508990   0.387511 -1.165133  0.260447
# 2       3.380003   0.483657 -0.528379 -0.497069
# 3      -0.464054  -0.810929 -0.446984 -0.976094
# 4      -0.415937   0.314386 -1.206770  0.229216
# ...          ...        ...       ...       ...
# 60588  -0.111192   0.460636 -0.851452  0.495732
# 60589  -0.362473  -0.756762 -0.837051 -0.389054
# 60590   0.156128   0.726054  0.085210  0.007785
# 60591  -0.437322   0.609595 -0.503334 -0.764759
# 60592  -0.458708  -0.383012  0.179126 -0.067356
#
# [60593 rows x 4 columns]

# %%
GWAS5_abs_diff_plus_log_odds_scores_norm
# Out:
#        BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                       -0.126976                        -0.393417
# 1                       -0.126990                        -0.520931
# 2                       -0.126986                        -0.070269
# 3                       -0.126972                         0.472467
# 4                        0.187447                        -0.504219
# ...                           ...                              ...
# 60588                   -0.149684                         0.137838
# 60589                   -0.149685                         0.619081
# 60590                   -0.149669                        -0.552165
# 60591                   -0.149715                        -0.307065
# 60592                   -0.149272                         0.452825
#
#        BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                         -0.170452                          -0.632455
# 1                         -0.170455                          -0.654701
# 2                         -0.170454                           0.927166
# 3                         -0.170417                           0.047169
# 4                          1.096573                           0.861540
# ...                             ...                                ...
# 60588                     -0.191819                          -0.651413
# 60589                     -0.191720                           0.859545
# 60590                     -0.191578                           0.431885
# 60591                     -0.191806                          -0.597963
# 60592                     -0.132168                           0.017757
#
#        BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                                -0.351548                    -0.150167
# 1                                -0.350676                    -0.150167
# 2                                -0.350216                    -0.150167
# 3                                 1.160915                    -0.150167
# 4                                -0.351674                     9.669863
# ...                                    ...                          ...
# 60588                            -0.427758                    -0.173886
# 60589                             1.969019                    -0.173885
# 60590                            -0.421645                    -0.173849
# 60591                            -0.430148                    -0.173882
# 60592                             6.278868                    -0.173885
#
#        BroadH1hescEzh239875UniPk151-ran  \
# 0                             -0.187212
# 1                             -0.186781
# 2                             -0.187213
# 3                              0.003889
# 4                             -0.187209
# ...                                 ...
# 60588                         -0.243942
# 60589                         -0.237051
# 60590                         -0.243689
# 60591                         -0.243784
# 60592                          2.211717
#
#        BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                                  -0.453192
# 1                                  -0.456035
# 2                                  -0.334202
# 3                                   1.015140
# 4                                  -0.451860
# ...                                      ...
# 60588                              -0.484972
# 60589                              -0.438271
# 60590                               0.040045
# 60591                              -0.522171
# 60592                               2.637769
#
#        BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                                 -0.273088                    -0.139205  ...
# 1                                 -0.273283                    -0.139208  ...
# 2                                 -0.272510                    -0.139189  ...
# 3                                  5.264016                    -0.139198  ...
# 4                                 -0.273132                    -0.138323  ...
# ...                                     ...                          ...  ...
# 60588                             -0.333870                    -0.172602  ...
# 60589                              0.581553                    -0.172599  ...
# 60590                             -0.346652                    -0.172596  ...
# 60591                             -0.347194                    -0.172567  ...
# 60592                             -0.265343                    -0.172602  ...
#
#        UwMcf7CtcfUniPk151-ran.1  UwNb4CtcfUniPk151-ran.1  \
# 0                     -0.303147                -0.184363
# 1                     -0.303420                -0.181288
# 2                     -0.304691                -0.177633
# 3                     -0.271336                -0.176117
# 4                      6.678783                -0.060616
# ...                         ...                      ...
# 60588                 -0.341056                -0.207251
# 60589                 -0.334840                -0.213731
# 60590                  1.878416                -0.197004
# 60591                 -0.334872                -0.211631
# 60592                 -0.104468                -0.221082
#
#        UwNhdfneoCtcfUniPk151-ran.1  UwNhekCtcfUniPk151-ran.1  \
# 0                        -0.346480                 -0.278705
# 1                        -0.377618                 -0.249286
# 2                        -0.118552                 -0.179786
# 3                        -0.365341                 -0.147491
# 4                        15.457387                 10.156484
# ...                            ...                       ...
# 60588                    -0.452988                 -0.268509
# 60589                    -0.459995                 -0.220215
# 60590                    -0.111108                  0.112052
# 60591                    -0.436338                 -0.267527
# 60592                    -0.312088                 -0.134559
#
#        UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                     -0.245373                  -0.026802
# 1                     -0.245114                  -0.334825
# 2                     -0.240982                  -0.242290
# 3                      0.296357                  -0.243272
# 4                      0.314958                  10.032747
# ...                         ...                        ...
# 60588                 -0.260146                  -0.245400
# 60589                 -0.162399                  -0.204531
# 60590                 -0.260145                  -0.309647
# 60591                 -0.123560                  -0.374008
# 60592                 -0.040855                  -0.128288
#
#        UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                     -0.414323                    -0.204780
# 1                     -0.430574                    -0.206213
# 2                     -0.314668                    -0.205791
# 3                     -0.436960                    -0.194768
# 4                      7.507830                     7.036562
# ...                         ...                          ...
# 60588                 -0.497364                    -0.241367
# 60589                 -0.465757                    -0.237332
# 60590                 -0.489733                    -0.240474
# 60591                 -0.484017                    -0.240110
# 60592                 -0.299522                    -0.239192
#
#        UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1
# 0                        -0.172762                 -0.236403
# 1                        -0.173918                 -0.273375
# 2                        -0.175968                 -0.275430
# 3                        -0.174534                 -0.232629
# 4                         8.389212                  1.659160
# ...                            ...                       ...
# 60588                    -0.209211                 -0.312707
# 60589                    -0.201387                 -0.319978
# 60590                    -0.077839                 -0.015910
# 60591                    -0.208981                 -0.295278
# 60592                    -0.210023                  0.940598
#
# [60593 rows x 1380 columns]

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
GWAS5_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([GWAS5_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
col_lab = list(range(0,1384))
GWAS5_abs_diff_plus_log_odds_and_cons_scores_norm = GWAS5_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
GWAS5_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/GWAS_SNP_1E-5_dataset_XY-named.txt", sep='\t')

# %%
y = GWAS5_prvcs['label']

# %%
GWAS5_pred = test_estimator.predict(GWAS5_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, GWAS5_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, GWAS5_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, GWAS5_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , GWAS5_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , GWAS5_pred)))
# Out:
# Accuracy_model_REG: 0.5171
# F1_model_REG: 0.1148
# MCC_model_REG: 0.0730
# ROC_AUC_model_REG: 0.5155
# Avg_Recall_Score_model_REG: 0.5085

# %% [markdown]
# Load Brown eQTL dataset

# %%
BWN_abs_diff_plus_log_odds_scores_norm = pd.read_csv(path_prefix + "DNABERT_2/output/BWN_0_67635-abs_diff_plus_log_odds_scores_norm_results_by_variant.csv", sep=',')

# %%
BWN_abs_diff_plus_log_odds_scores_norm.shape
# Out:
# (67635, 1380)

# %%
cons_scores = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Brown_eQTL_dataset_XY-named-plus-rs-dscons.csv", sep=',')
cons_scores.head(), cons_scores.shape
# Out:
# (       Name  priPhCons  priPhyloP  GerpN   GerpS
#  0  BRN00001      0.028     -1.870   0.00  0.0000
#  1  BRN00002      0.000     -0.496   1.31 -2.4600
#  2  BRN00003      0.001     -0.493   2.12 -0.0176
#  3  BRN00004      0.000     -0.301   2.93 -5.8500
#  4  BRN00005      0.002      0.392   2.69 -1.1600,
#  (67635, 5))

# %%
cons_scores = cons_scores.drop(['Name'], axis=1)

# %%
cons_scores
# Out:
#        priPhCons  priPhyloP  GerpN   GerpS
# 0          0.028     -1.870   0.00  0.0000
# 1          0.000     -0.496   1.31 -2.4600
# 2          0.001     -0.493   2.12 -0.0176
# 3          0.000     -0.301   2.93 -5.8500
# 4          0.002      0.392   2.69 -1.1600
# ...          ...        ...    ...     ...
# 67630      0.115     -0.033   0.00  0.0000
# 67631      0.020      0.144   0.00  0.0000
# 67632      0.206      0.185   2.53  0.6080
# 67633      0.035      0.121   0.00  0.0000
# 67634      0.012      0.342   1.59 -1.9900
#
# [67635 rows x 4 columns]

# %%
from scipy.stats import zscore

cons_scores_norm = cons_scores.apply(lambda x: zscore(x, ddof=1))

# %%
cons_scores_norm
# Out:
#        priPhCons  priPhyloP     GerpN     GerpS
# 0      -0.307058  -2.413248 -1.272719  0.246652
# 1      -0.476589  -0.531261 -0.417647 -0.933069
# 2      -0.470535  -0.527152  0.111061  0.238212
# 3      -0.476589  -0.264166  0.639770 -2.558783
# 4      -0.464480   0.685046  0.483116 -0.309639
# ...          ...        ...       ...       ...
# 67630   0.219702   0.102917 -1.272719  0.246652
# 67631  -0.355495   0.345356 -1.272719  0.246652
# 67632   0.770680   0.401515  0.378679  0.538225
# 67633  -0.264675   0.313853 -1.272719  0.246652
# 67634  -0.403933   0.616560 -0.234884 -0.707675
#
# [67635 rows x 4 columns]

# %%
BWN_abs_diff_plus_log_odds_scores_norm
# Out:
#        BroadDnd41CtcfUniPk151-ran  BroadDnd41Ezh239875UniPk151-ran  \
# 0                       -0.135348                        -0.345069
# 1                       -0.136769                        -0.508324
# 2                        0.002618                         0.139306
# 3                       -0.136750                        -0.556679
# 4                       -0.136769                        -0.554759
# ...                           ...                              ...
# 67630                    0.426762                        -0.519993
# 67631                   -0.163057                        -0.387676
# 67632                   -0.162968                        -0.542903
# 67633                   -0.163057                        -0.542535
# 67634                   -0.163002                         1.152725
#
#        BroadGm12878CtcfUniPk151-ran  BroadGm12878Ezh239875UniPk151-ran  \
# 0                         -0.168924                           0.863123
# 1                         -0.177759                          -0.700927
# 2                          1.125427                           0.045734
# 3                         -0.177762                          -0.705941
# 4                         -0.177761                          -0.708032
# ...                             ...                                ...
# 67630                      2.389886                          -0.667262
# 67631                     -0.203723                          -0.704594
# 67632                     -0.148704                          -0.616780
# 67633                     -0.203727                          -0.733295
# 67634                     -0.203314                           2.174047
#
#        BroadH1hescChd1a301218aUniPk151-ran  BroadH1hescCtcfUniPk151-ran  \
# 0                                -0.034798                    -0.037808
# 1                                -0.384701                    -0.157779
# 2                                 0.050726                    -0.157706
# 3                                -0.384427                    -0.157779
# 4                                -0.384690                    -0.157779
# ...                                    ...                          ...
# 67630                            -0.392921                     1.469699
# 67631                            -0.394300                    -0.183098
# 67632                            -0.394467                    -0.180621
# 67633                            -0.392377                    -0.183098
# 67634                            -0.150486                    -0.183098
#
#        BroadH1hescEzh239875UniPk151-ran  \
# 0                             -0.200140
# 1                             -0.201242
# 2                              0.710525
# 3                             -0.201277
# 4                             -0.201269
# ...                                 ...
# 67630                         -0.242239
# 67631                         -0.242126
# 67632                         -0.242148
# 67633                         -0.242255
# 67634                         -0.231924
#
#        BroadH1hescJarid1aab26049UniPk151-ran  \
# 0                                  -0.418137
# 1                                  -0.490331
# 2                                   1.317889
# 3                                  -0.491218
# 4                                  -0.490493
# ...                                      ...
# 67630                              -0.475929
# 67631                              -0.481876
# 67632                              -0.482742
# 67633                              -0.483691
# 67634                               2.228075
#
#        BroadH1hescRbbp5a300109aUniPk151-ran  BroadHelas3CtcfUniPk151-ran  ...  \
# 0                                 -0.281413                     0.576187  ...
# 1                                 -0.304740                    -0.159794  ...
# 2                                  0.011336                    -0.129497  ...
# 3                                 -0.304722                    -0.159793  ...
# 4                                 -0.304724                    -0.159793  ...
# ...                                     ...                          ...  ...
# 67630                             -0.333431                     0.132209  ...
# 67631                             -0.333707                    -0.177585  ...
# 67632                             -0.013730                    -0.176840  ...
# 67633                             -0.333663                    -0.177584  ...
# 67634                             -0.228134                    -0.177574  ...
#
#        UwMcf7CtcfUniPk151-ran.1  UwNb4CtcfUniPk151-ran.1  \
# 0                      0.108417                -0.147086
# 1                     -0.319620                -0.193400
# 2                     -0.252883                -0.164831
# 3                     -0.317318                -0.191479
# 4                     -0.292412                -0.194009
# ...                         ...                      ...
# 67630                  0.545519                -0.017602
# 67631                 -0.347135                -0.237054
# 67632                 -0.326373                -0.218202
# 67633                 -0.346243                -0.237949
# 67634                 -0.350577                -0.234990
#
#        UwNhdfneoCtcfUniPk151-ran.1  UwNhekCtcfUniPk151-ran.1  \
# 0                         0.237138                 -0.222720
# 1                        -0.411612                 -0.271661
# 2                         0.620072                  0.005501
# 3                        -0.405643                 -0.303477
# 4                        -0.403530                 -0.288284
# ...                            ...                       ...
# 67630                     1.987220                  0.871608
# 67631                    -0.413078                 -0.274326
# 67632                     0.329758                 -0.263105
# 67633                    -0.413319                 -0.300008
# 67634                    -0.169940                 -0.290063
#
#        UwNhlfCtcfUniPk151-ran.1  UwRptecCtcfUniPk151-ran.1  \
# 0                      0.020309                  -0.064837
# 1                     -0.248266                  -0.335923
# 2                     -0.241039                   0.271412
# 3                     -0.258323                  -0.335417
# 4                     -0.188400                  -0.242840
# ...                         ...                        ...
# 67630                 -0.283313                   0.273685
# 67631                 -0.264960                  -0.327722
# 67632                 -0.185263                  -0.341422
# 67633                 -0.288435                  -0.350085
# 67634                 -0.286679                  -0.302591
#
#        UwSaecCtcfUniPk151-ran.1  UwSknshraCtcfUniPk151-ran.1  \
# 0                      0.067443                     0.089623
# 1                     -0.475786                    -0.221497
# 2                      0.162022                     5.676635
# 3                     -0.480505                    -0.216404
# 4                     -0.478283                    -0.219369
# ...                         ...                          ...
# 67630                 -0.011059                     0.329961
# 67631                 -0.501083                    -0.269499
# 67632                 -0.444358                    -0.260462
# 67633                 -0.505341                    -0.268147
# 67634                 -0.492904                    -0.267273
#
#        UwWerirb1CtcfUniPk151-ran.1  UwWi38CtcfUniPk151-ran.1
# 0                        -0.184572                  0.017552
# 1                        -0.182946                 -0.266036
# 2                        -0.102966                 -0.145503
# 3                        -0.181079                 -0.293622
# 4                        -0.179563                 -0.267128
# ...                            ...                       ...
# 67630                    -0.199151                  0.825402
# 67631                    -0.227322                 -0.325402
# 67632                    -0.229031                 -0.348364
# 67633                    -0.232223                 -0.332598
# 67634                    -0.224739                 -0.326815
#
# [67635 rows x 1380 columns]

# %%
# abs_diff_plus_log_odds_and_cons_scores = pd.concat([abs_diff_plus_log_odds_scores_norm,cons_scores], axis=1)
BWN_abs_diff_plus_log_odds_and_cons_scores_norm = pd.concat([BWN_abs_diff_plus_log_odds_scores_norm,cons_scores_norm], axis=1)

# %%
BWN_abs_diff_plus_log_odds_and_cons_scores_norm.shape
# Out:
# (67635, 1384)

# %%
col_lab = list(range(0,1384))
BWN_abs_diff_plus_log_odds_and_cons_scores_norm = BWN_abs_diff_plus_log_odds_and_cons_scores_norm.set_axis(col_lab, axis="columns")

# %%
BWN_prvcs = pd.read_csv(path_prefix + "DNABERT_2/Datasets/PRVCS/test_dataset/Brown_eQTL_dataset_XY-named.txt", sep='\t')

# %%
y = BWN_prvcs['label']

# %%
BWN_pred = test_estimator.predict(BWN_abs_diff_plus_log_odds_and_cons_scores_norm)

# %%
print("Accuracy_model_REG: %.4f" % (accuracy_score(y, BWN_pred)))  
print("F1_model_REG: %.4f" % (f1_score(y, BWN_pred)))  
print("MCC_model_REG: %.4f" % (matthews_corrcoef(y, BWN_pred)))  
print("ROC_AUC_model_REG: %.4f" % (roc_auc_score(y , BWN_pred)))
print("Avg_Recall_Score_model_REG: %.4f" % (average_precision_score(y , BWN_pred)))
# Out:
# Accuracy_model_REG: 0.5475
# F1_model_REG: 0.1021
# MCC_model_REG: 0.0542
# ROC_AUC_model_REG: 0.5111
# Avg_Recall_Score_model_REG: 0.4671
